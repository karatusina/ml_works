# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import date
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklego.preprocessing import RepeatingBasisFunction
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [raw]
# df = pd.read_csv("https://raw.githubusercontent.com/katarina74/ml_lessons/main/lesson_2/data/techparams_train.csv")
# df.head()

# %%
df = pd.read_csv('techparams_train.csv')
df.head()
# Out:
#    index  back-suspension  battery-capacity  charge-time  compression  \
# 0      0                9              -1.0        36457          9.0
# 1      2                3              -1.0        44872          8.0
# 2      4                3              -1.0        55927         16.0
# 3      5                0              -1.0        41405         10.3
# 4      7                8              -1.0        22523         19.0
#
#    consumption-mixed  cylinders-order  cylinders-value  engine-feeding  \
# 0                4.3                0                3               4
# 1               -1.0                3                7               4
# 2                4.2                0                4               5
# 3               -1.0                0                4               4
# 4               -1.0                0                4               8
#
#    engine-start  ...  configurations_front-brake  \
# 0          2006  ...                           1
# 1          1982  ...                           4
# 2          2014  ...                           4
# 3          2000  ...                           4
# 4          2000  ...                           4
#
#    configurations_safety-rating  configurations_seats  \
# 0                             2                    13
# 1                             2                    13
# 2                             2                    13
# 3                             2                    13
# 4                             1                    13
#
#    configurations_tank-volume  supergen_year-stop  models_country-from  \
# 0                        40.0              2018.0                   16
# 1                       108.0              1993.0                   34
# 2                        55.0              2019.0                   35
# 3                        55.0              2003.0                   10
# 4                        62.0              2005.0                   10
#
#    models_group  models_light-and-commercial  models_male  target
# 0             3                            0            1    2360
# 1             3                            0            1    3060
# 2             3                            0            1    2648
# 3             3                            0            1    2513
# 4             3                            0            1    2703
#
# [5 rows x 32 columns]

# %% [markdown]
# Данные: технические характеристики разных конфигураций автомобилей
#
# Таргет: длина колесной базы конфигурации (в миллиметрах).
#
# Задача: добиться наименьшего MSE на test.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43245 entries, 0 to 43244
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   index                           43245 non-null  int64
#  1   back-suspension                 43245 non-null  int64
#  2   battery-capacity                43245 non-null  float64
#  3   charge-time                     43245 non-null  int64
#  4   compression                     43245 non-null  float64
#  5   consumption-mixed               43245 non-null  float64
#  6   cylinders-order                 43245 non-null  int64
#  7   cylinders-value                 43245 non-null  int64
#  8   engine-feeding                  43245 non-null  int64
#  9   engine-start                    43245 non-null  int64
#  10  engine-stop                     43245 non-null  int64
#  11  engine-type                     43245 non-null  int64
#  12  gear-type                       43245 non-null  int64
#  13  luxury                          43245 non-null  int64
#  14  max-speed                       43245 non-null  float64
#  15  power-electro-kw                43245 non-null  float64
#  16  supply-system                   43245 non-null  int64
#  17  valves                          43245 non-null  int64
#  18  valvetrain                      43245 non-null  int64
#  19  weight                          43245 non-null  float64
#  20  configurations_auto-premiere    43245 non-null  int64
#  21  configurations_back-wheel-base  43245 non-null  float64
#  22  configurations_front-brake      43245 non-null  int64
#  23  configurations_safety-rating    43245 non-null  int64
#  24  configurations_seats            43245 non-null  int64
#  25  configurations_tank-volume      43245 non-null  float64
#  26  supergen_year-stop              43245 non-null  float64
#  27  models_country-from             43245 non-null  int64
#  28  models_group                    43245 non-null  int64
#  29  models_light-and-commercial     43245 non-null  int64
#  30  models_male                     43245 non-null  int64
#  31  target                          43245 non-null  int64
# dtypes: float64(9), int64(23)
# memory usage: 10.6 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.T.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Можем удалить столбец с индексами, поскольку они почти полностью дублируют сами индексы

# %%
df = df.drop(columns='index')

# %%
df.head()
# Out:
#    back-suspension  battery-capacity  charge-time  compression  \
# 0                9              -1.0        36457          9.0
# 1                3              -1.0        44872          8.0
# 2                3              -1.0        55927         16.0
# 3                0              -1.0        41405         10.3
# 4                8              -1.0        22523         19.0
#
#    consumption-mixed  cylinders-order  cylinders-value  engine-feeding  \
# 0                4.3                0                3               4
# 1               -1.0                3                7               4
# 2                4.2                0                4               5
# 3               -1.0                0                4               4
# 4               -1.0                0                4               8
#
#    engine-start  engine-stop  ...  configurations_front-brake  \
# 0          2006         2018  ...                           1
# 1          1982         1993  ...                           4
# 2          2014         2018  ...                           4
# 3          2000         2003  ...                           4
# 4          2000         2005  ...                           4
#
#    configurations_safety-rating  configurations_seats  \
# 0                             2                    13
# 1                             2                    13
# 2                             2                    13
# 3                             2                    13
# 4                             1                    13
#
#    configurations_tank-volume  supergen_year-stop  models_country-from  \
# 0                        40.0              2018.0                   16
# 1                       108.0              1993.0                   34
# 2                        55.0              2019.0                   35
# 3                        55.0              2003.0                   10
# 4                        62.0              2005.0                   10
#
#    models_group  models_light-and-commercial  models_male  target
# 0             3                            0            1    2360
# 1             3                            0            1    3060
# 2             3                            0            1    2648
# 3             3                            0            1    2513
# 4             3                            0            1    2703
#
# [5 rows x 31 columns]

# %%
sns.heatmap(df.corr())
plt.show()

# %%
#найдем переменные с наиболее высокой корреляцией с помощью корреляционной матрицы
correlation_matrix = df.corr()

#оставим только корреляцию с target
correlation_with_target = pd.DataFrame(data=correlation_matrix['target'])
#выведем в красивом формате
correlation_with_target.sort_values(by='target', ascending=False).T
# Out:
#         target  cylinders-value  configurations_tank-volume  cylinders-order  \
# target     1.0         0.472177                    0.413853         0.376272
#
#           weight  configurations_seats  configurations_front-brake  \
# target  0.339835              0.298625                    0.184791
#
#         engine-start  models_country-from  consumption-mixed  ...  valvetrain  \
# target      0.150944             0.148848           0.118195  ...     0.02112
#
#         engine-feeding  models_male  configurations_safety-rating  \
# target        0.012235     0.003423                     -0.007558
#
#         models_group    valves  engine-type  supergen_year-stop  engine-stop  \
# target     -0.031663 -0.066402    -0.125304           -0.136986    -0.137719
#
#         back-suspension
# target        -0.159912
#
# [1 rows x 31 columns]

# %%
X_best = df[['cylinders-value', "configurations_tank-volume", "cylinders-order", 'weight',
'configurations_seats', 'configurations_front-brake', 'engine-start', 'models_country-from',
'consumption-mixed', 'engine-type', 'supergen_year-stop', 'engine-stop', 'back-suspension']]
y = df[['target']]

train_X_b, test_X_b, train_y, test_y = train_test_split(X_best, y, test_size=0.33, random_state=42)

# %%
train_X_b
# Out:
#        cylinders-value  configurations_tank-volume  cylinders-order  weight  \
# 22607                4                        50.0                0  1290.0
# 36531                4                        48.0                0   935.0
# 24048                4                        56.0                0  1373.0
# 34819                4                        56.0                0  1430.0
# 1328                 5                        70.0                0  1485.0
# ...                ...                         ...              ...     ...
# 6265                 4                        68.0                0  1655.0
# 11284                7                        82.0                3    -1.0
# 38158                4                        62.0                0  1562.0
# 860                  4                        50.0                0    -1.0
# 15795                7                        66.0                3  1745.0
#
#        configurations_seats  configurations_front-brake  engine-start  \
# 22607                    13                           4          1997
# 36531                    13                           1          1990
# 24048                    13                           4          2009
# 34819                    13                           4          2015
# 1328                     13                           4          2004
# ...                     ...                         ...           ...
# 6265                     13                           4          2017
# 11284                    13                           4          1987
# 38158                    13                           4          2018
# 860                      13                           1          1992
# 15795                     8                           4          2004
#
#        models_country-from  consumption-mixed  engine-type  \
# 22607                   16               -1.0            2
# 36531                   23               -1.0            2
# 24048                   10                6.8            2
# 34819                   16                5.3            0
# 1328                    28                7.5            0
# ...                    ...                ...          ...
# 6265                    10                4.7            0
# 11284                   34               -1.0            2
# 38158                   26                7.6            2
# 860                     16               -1.0            0
# 15795                   35               -1.0            2
#
#        supergen_year-stop  engine-stop  back-suspension
# 22607              2000.0         2000                3
# 36531              1996.0         1993                8
# 24048              2012.0         2012                8
# 34819              2017.0         2017                3
# 1328               2009.0         2005                3
# ...                   ...          ...              ...
# 6265                 -1.0            0                6
# 11284              1996.0         1990                0
# 38158                -1.0            0                3
# 860                1995.0         1995               10
# 15795              2007.0         2007                3
#
# [28974 rows x 13 columns]

# %%
test_X_b.head()
# Out:
#        cylinders-value  configurations_tank-volume  cylinders-order  weight  \
# 22894                4                        -1.0                0    -1.0
# 27055                6                        -1.0                0    -1.0
# 40027                4                        45.0                0  1163.0
# 41228                3                        37.0                0   760.0
# 20814                4                        70.0                0  1425.0
#
#        configurations_seats  configurations_front-brake  engine-start  \
# 22894                     4                           1          1984
# 27055                    13                           1          1977
# 40027                    13                           4          2012
# 41228                    13                           1          1987
# 20814                    13                           4          2004
#
#        models_country-from  consumption-mixed  engine-type  \
# 22894                   35               -1.0            2
# 27055                   34               -1.0            2
# 40027                   34                5.5            2
# 41228                   16               -1.0            2
# 20814                   10               -1.0            2
#
#        supergen_year-stop  engine-stop  back-suspension
# 22894              1988.0         1988               10
# 27055              1986.0         1982               10
# 40027              2014.0         2014                8
# 41228              1993.0         1993                3
# 20814              2009.0         2008                3

# %% [markdown]
# # Linear Regression

# %%
reg_b = LinearRegression().fit(train_X_b, train_y)

# %%
#смотрим коэффикиент детерминации
reg_b.score(train_X_b, train_y), reg_b.score(test_X_b, test_y)
#видим,что коэффициент детерминации относительно невысокий - 
#возможно, имеет смысл рассматривать связь со всеми признаками
# Out:
# (0.4171766084205437, 0.42622292092455705)

# %%
#Рассмотрим также и MSE, минимальное значение которого нам надо получить
mean_squared_error(reg_b.predict(train_X_b), train_y), mean_squared_error(reg_b.predict(test_X_b), test_y)
#далее рассмотрим значения MSE при включении всех столбцов в х
# Out:
# (np.float64(31942.736557040367), np.float64(33246.103725106026))

# %% [markdown]
# Бинарная:<br> <code>models_light-and-commercial </code>

# %%
X = df.drop(['target'], axis=1)
y = df[['target']]

train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
train_X.head()
# Out:
#        back-suspension  battery-capacity  charge-time  compression  \
# 22607                3              -1.0        11636          9.5
# 36531                8              -1.0        31764          9.0
# 24048                8              -1.0         2773          8.8
# 34819                3              -1.0        52039         14.0
# 1328                 3              -1.0        20689         18.0
#
#        consumption-mixed  cylinders-order  cylinders-value  engine-feeding  \
# 22607               -1.0                0                4               4
# 36531               -1.0                0                4               0
# 24048                6.8                0                4               4
# 34819                5.3                0                4               5
# 1328                 7.5                0                5               5
#
#        engine-start  engine-stop  ...  configurations_back-wheel-base  \
# 22607          1997         2000  ...                          1415.0
# 36531          1990         1993  ...                          1310.0
# 24048          2009         2012  ...                          1558.0
# 34819          2015         2017  ...                          1590.0
# 1328           2004         2005  ...                          1560.0
#
#        configurations_front-brake  configurations_safety-rating  \
# 22607                           4                             2
# 36531                           1                             2
# 24048                           4                             1
# 34819                           4                             2
# 1328                            4                             2
#
#        configurations_seats  configurations_tank-volume  supergen_year-stop  \
# 22607                    13                        50.0              2000.0
# 36531                    13                        48.0              1996.0
# 24048                    13                        56.0              2012.0
# 34819                    13                        56.0              2017.0
# 1328                     13                        70.0              2009.0
#
#        models_country-from  models_group  models_light-and-commercial  \
# 22607                   16             3                            0
# 36531                   23             3                            0
# 24048                   10             3                            0
# 34819                   16             3                            0
# 1328                    28             3                            0
#
#        models_male
# 22607            1
# 36531            0
# 24048            1
# 34819            0
# 1328             1
#
# [5 rows x 30 columns]

# %%
reg = LinearRegression().fit(train_X, train_y)

# %%
#смотрим коэффикиент детерминации
reg.score(train_X, train_y), reg.score(test_X, test_y)
#показатели несколько лучше, чем в прошлый раз
# Out:
# (0.45548738550350776, 0.4647153732232179)

# %%
#Рассмотрим также и MSE, минимальное значение которого нам надо получить
mean_squared_error(reg.predict(train_X), train_y), mean_squared_error(reg.predict(test_X), test_y)
#Показатель MSE также лучше (меньше), чем в прошлый раз
# Out:
# (np.float64(29843.04207439402), np.float64(31015.75310911931))

# %% [markdown]
# # Кодирование с синусом / косинусом

# %%
def sin_transformer(period):
 return FunctionTransformer(lambda x: np.sin(x / period * 2 * np.pi))

def cos_transformer(period):
 return FunctionTransformer(lambda x: np.cos(x / period * 2 * np.pi))

# %%
X.head()
# Out:
#    back-suspension  battery-capacity  charge-time  compression  \
# 0                9              -1.0        36457          9.0
# 1                3              -1.0        44872          8.0
# 2                3              -1.0        55927         16.0
# 3                0              -1.0        41405         10.3
# 4                8              -1.0        22523         19.0
#
#    consumption-mixed  cylinders-order  cylinders-value  engine-feeding  \
# 0                4.3                0                3               4
# 1               -1.0                3                7               4
# 2                4.2                0                4               5
# 3               -1.0                0                4               4
# 4               -1.0                0                4               8
#
#    engine-start  engine-stop  ...  configurations_back-wheel-base  \
# 0          2006         2018  ...                          1300.0
# 1          1982         1993  ...                          1555.0
# 2          2014         2018  ...                          1534.0
# 3          2000         2003  ...                          1495.0
# 4          2000         2005  ...                          1515.0
#
#    configurations_front-brake  configurations_safety-rating  \
# 0                           1                             2
# 1                           4                             2
# 2                           4                             2
# 3                           4                             2
# 4                           4                             1
#
#    configurations_seats  configurations_tank-volume  supergen_year-stop  \
# 0                    13                        40.0              2018.0
# 1                    13                       108.0              1993.0
# 2                    13                        55.0              2019.0
# 3                    13                        55.0              2003.0
# 4                    13                        62.0              2005.0
#
#    models_country-from  models_group  models_light-and-commercial  models_male
# 0                   16             3                            0            1
# 1                   34             3                            0            1
# 2                   35             3                            0            1
# 3                   10             3                            0            1
# 4                   10             3                            0            1
#
# [5 rows x 30 columns]

# %%
X_2 = X.copy()
for i in range(len(X_2.columns)):
    name = X_2.columns[i]
    name_sin = X_2.columns[i] + '_sin'
    name_cos = X_2.columns[i] + '_cos'
    X_2[name_sin] = sin_transformer(X_2[name].nunique()).fit_transform(X_2)[name]
    X_2[name_cos] = sin_transformer(X_2[name].nunique()).fit_transform(X_2)[name]
X_2.head(3)
# Out:
#    back-suspension  battery-capacity  charge-time  compression  \
# 0                9              -1.0        36457          9.0
# 1                3              -1.0        44872          8.0
# 2                3              -1.0        55927         16.0
#
#    consumption-mixed  cylinders-order  cylinders-value  engine-feeding  \
# 0                4.3                0                3               4
# 1               -1.0                3                7               4
# 2                4.2                0                4               5
#
#    engine-start  engine-stop  ...  supergen_year-stop_sin  \
# 0          2006         2018  ...               -0.942732
# 1          1982         1993  ...               -0.287378
# 2          2014         2018  ...               -0.919164
#
#    supergen_year-stop_cos  models_country-from_sin  models_country-from_cos  \
# 0               -0.942732                 0.342020                 0.342020
# 1               -0.287378                -0.342020                -0.342020
# 2               -0.919164                -0.173648                -0.173648
#
#    models_group_sin  models_group_cos  models_light-and-commercial_sin  \
# 0              -1.0              -1.0                              0.0
# 1              -1.0              -1.0                              0.0
# 2              -1.0              -1.0                              0.0
#
#    models_light-and-commercial_cos  models_male_sin  models_male_cos
# 0                              0.0         0.013397         0.013397
# 1                              0.0         0.013397         0.013397
# 2                              0.0         0.013397         0.013397
#
# [3 rows x 90 columns]

# %%
train_end = train_X.shape[0]

X_2_sin_cos = X_2.drop(['back-suspension', 'battery-capacity', 'charge-time', 'compression', 'consumption-mixed', 'cylinders-order', 
                         'cylinders-value', 'engine-feeding', 'engine-start', 'engine-stop', 'engine-type','gear-type', 'luxury', 
                         'max-speed', 'power-electro-kw', 'supply-system', 'valves', 'valvetrain','weight','configurations_auto-premiere',
                         'configurations_back-wheel-base', 'configurations_front-brake', 'configurations_safety-rating',
                         'configurations_seats','configurations_tank-volume', 'supergen_year-stop','models_country-from', 'models_group', 
                         'models_light-and-commercial', 'models_male'], axis=1)

# %%
model_2 = LinearRegression().fit(X_2_sin_cos.iloc[:train_end], y.iloc[:train_end])

# %%
mean_squared_error(model_2.predict(X_2_sin_cos.iloc[:train_end]), train_y)
# Out:
# np.float64(82330.90976361895)

# %% [markdown]
# MSE выше, чем по всех предыдущих случаях

# %% [markdown]
# ## Попробуем использовать только переменные, имеющие лучшую связь с длиной колесной базы

# %%
X_2_best = X_best.copy()
X_2_best.head(1)
# Out:
#    cylinders-value  configurations_tank-volume  cylinders-order  weight  \
# 0                3                        40.0                0   820.0
#
#    configurations_seats  configurations_front-brake  engine-start  \
# 0                    13                           1          2006
#
#    models_country-from  consumption-mixed  engine-type  supergen_year-stop  \
# 0                   16                4.3            2              2018.0
#
#    engine-stop  back-suspension
# 0         2018                9

# %%
for i in range(len(X_2_best.columns)):
    name = X_2_best.columns[i]
    name_sin = X_2_best.columns[i] + '_sin'
    name_cos = X_2_best.columns[i] + '_cos'
    X_2_best[name_sin] = sin_transformer(X_2_best[name].nunique()).fit_transform(X_2_best)[name]
    X_2_best[name_cos] = sin_transformer(X_2_best[name].nunique()).fit_transform(X_2_best)[name]
X_2_best.head(3)
# Out:
#    cylinders-value  configurations_tank-volume  cylinders-order  weight  \
# 0                3                        40.0                0   820.0
# 1                7                       108.0                3  2350.0
# 2                4                        55.0                0  1350.0
#
#    configurations_seats  configurations_front-brake  engine-start  \
# 0                    13                           1          2006
# 1                    13                           4          1982
# 2                    13                           4          2014
#
#    models_country-from  consumption-mixed  engine-type  ...  \
# 0                   16                4.3            2  ...
# 1                   34               -1.0            2  ...
# 2                   35                4.2            0  ...
#
#    consumption-mixed_sin  consumption-mixed_cos  engine-type_sin  \
# 0               0.131412               0.131412         0.587785
# 1              -0.030645              -0.030645         0.587785
# 2               0.128373               0.128373         0.000000
#
#    engine-type_cos  supergen_year-stop_sin  supergen_year-stop_cos  \
# 0         0.587785               -0.942732               -0.942732
# 1         0.587785               -0.287378               -0.287378
# 2         0.000000               -0.919164               -0.919164
#
#    engine-stop_sin  engine-stop_cos  back-suspension_sin  back-suspension_cos
# 0        -0.942732        -0.942732            -0.909632            -0.909632
# 1        -0.287378        -0.287378             0.989821             0.989821
# 2        -0.942732        -0.942732             0.989821             0.989821
#
# [3 rows x 39 columns]

# %%
X_2_best.columns
# Out:
# Index(['cylinders-value', 'configurations_tank-volume', 'cylinders-order',
#        'weight', 'configurations_seats', 'configurations_front-brake',
#        'engine-start', 'models_country-from', 'consumption-mixed',
#        'engine-type', 'supergen_year-stop', 'engine-stop', 'back-suspension',
#        'cylinders-value_sin', 'cylinders-value_cos',
#        'configurations_tank-volume_sin', 'configurations_tank-volume_cos',
#        'cylinders-order_sin', 'cylinders-order_cos', 'weight_sin',
#        'weight_cos', 'configurations_seats_sin', 'configurations_seats_cos',
#        'configurations_front-brake_sin', 'configurations_front-brake_cos',
#        'engine-start_sin', 'engine-start_cos', 'models_country-from_sin',
#        'models_country-from_cos', 'consumption-mixed_sin',
#        'consumption-mixed_cos', 'engine-type_sin', 'engine-type_cos',
#        'supergen_year-stop_sin', 'supergen_year-stop_cos', 'engine-stop_sin',
#        'engine-stop_cos', 'back-suspension_sin', 'back-suspension_cos'],
#       dtype='object')

# %%
train_end = train_X_b.shape[0]

X_2_best_sin_cos = X_2_best.drop(['cylinders-value', 'configurations_tank-volume', 'cylinders-order', 'weight', 'configurations_seats', 
                        'configurations_front-brake', 'engine-start', 'models_country-from', 'consumption-mixed', 'engine-type', 
                        'supergen_year-stop', 'engine-stop', 'back-suspension'], axis=1)
X_2_best_sin_cos.head(2)
# Out:
#    cylinders-value_sin  cylinders-value_cos  configurations_tank-volume_sin  \
# 0             0.989821             0.989821                        0.755750
# 1            -0.755750            -0.755750                       -0.113991
#
#    configurations_tank-volume_cos  cylinders-order_sin  cylinders-order_cos  \
# 0                        0.755750             0.000000             0.000000
# 1                       -0.113991             0.433884             0.433884
#
#    weight_sin  weight_cos  configurations_seats_sin  configurations_seats_cos  \
# 0   -0.058506   -0.058506                  0.673696                  0.673696
# 1    0.250957    0.250957                  0.673696                  0.673696
#
#    ...  consumption-mixed_sin  consumption-mixed_cos  engine-type_sin  \
# 0  ...               0.131412               0.131412         0.587785
# 1  ...              -0.030645              -0.030645         0.587785
#
#    engine-type_cos  supergen_year-stop_sin  supergen_year-stop_cos  \
# 0         0.587785               -0.942732               -0.942732
# 1         0.587785               -0.287378               -0.287378
#
#    engine-stop_sin  engine-stop_cos  back-suspension_sin  back-suspension_cos
# 0        -0.942732        -0.942732            -0.909632            -0.909632
# 1        -0.287378        -0.287378             0.989821             0.989821
#
# [2 rows x 26 columns]

# %%
model_2_best = LinearRegression().fit(X_2_best_sin_cos.iloc[:train_end], y.iloc[:train_end])

# %%
mean_squared_error(model_2_best.predict(X_2_best_sin_cos.iloc[:train_end]), train_y)
# Out:
# np.float64(81556.33968831366)

# %% [markdown]
# MSE выше, чем по всех предыдущих случаях, кроме случая кодирования, но по всем переменным

# %% [markdown]
# # Радиальные базисные функции

# %% [markdown]
# RepeatingBasisFunction [применяется только к циклическим данным](https://koaning.github.io/scikit-lego/api/preprocessing/#sklego.preprocessing.repeatingbasis.RepeatingBasisFunction), но в нашем случае данные не являются циклическими. В связи с этим, преобразование не будет корректным

# %%
y['target'].plot()
plt.show()

# %% [markdown]
# # Приведем данные к единой шкале

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# ## MinMaxScaler

# %%
X_3 = X.copy()

scaler = MinMaxScaler()
X_minmax = scaler.fit_transform(X_3)

# %%
train_X_mm, test_X_mm, train_y, test_y = train_test_split(X_minmax, y, test_size=0.33, random_state=42)

# %%
reg_mm = LinearRegression().fit(train_X_mm, train_y)

# %%
mean_squared_error(reg_mm.predict(train_X_mm), train_y), mean_squared_error(reg_mm.predict(test_X_mm), test_y)
# Out:
# (np.float64(29843.04207439402), np.float64(31015.753109119247))

# %% [markdown]
# Получили, на данный момент, наименьшую MSE

# %% [markdown]
# ## StandartScaler

# %%
X_4 = X.copy()

scaler = MinMaxScaler()
X_ss = scaler.fit_transform(X_4)

# %%
train_X_ss, test_X_ss, train_y, test_y = train_test_split(X_ss, y, test_size=0.33, random_state=42)

# %%
reg_ss = LinearRegression().fit(train_X_ss, train_y)

# %%
mean_squared_error(reg_ss.predict(train_X_ss), train_y), mean_squared_error(reg_ss.predict(test_X_ss), test_y)
# Out:
# (np.float64(29843.04207439402), np.float64(31015.753109119247))

# %% [markdown]
# ## Логарифмирование

# %%
X_5 = X.copy()
#X_5[X_5 < 0] = np.nan
transformed_X_5 = np.log(X_5)
train_X_log, test_X_log, train_y, test_y = train_test_split(transformed_X_5, y, test_size=0.33, random_state=42)
# Out:
# C:\Users\96234\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:393: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# C:\Users\96234\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)

# %% [markdown]
# Необходимо преобразовать отрицательные (и нулевые) значения, чтобы в дальнейшем не получить ошибку

# %%
neg_values = [
    (X_5[X_5[name] < 0][name].unique(), name) 
    for name in X_5.columns 
    if len(X_5[X_5[name] < 0][name].unique()) > 0
]

neg_values_cols = []

for i in range(len(neg_values)):
    neg_values_cols.append(neg_values[i][1])
neg_values_cols
# Out:
# ['battery-capacity',
#  'compression',
#  'consumption-mixed',
#  'max-speed',
#  'power-electro-kw',
#  'weight',
#  'configurations_back-wheel-base',
#  'configurations_tank-volume',
#  'supergen_year-stop']

# %%
for i in range(len(neg_values_cols)):
    name = neg_values_cols[i]
    print(X_5[name].unique(), name)
# Out:
# [ -1.    13.2   21.     1.56  41.    10.7    1.3   23.     6.5   90.
#   18.4  100.    14.1    9.2  130.    24.    75.    13.5    1.4   17.6
#   12.    21.3   31.3   58.    78.    60.    22.    18.8   40.     4.4
#   30.    45.     8.7  120.    62.    50.    10.4    1.1   27.2  200.
#   33.     6.8   93.4    1.31  64.    32.6    9.27  11.6    7.6    5.5
#   14.4   16.    79.2   41.4   31.2   28.     1.5   13.    77.    17.1
#    7.9   42.2   47.17  95.    37.    16.5   25.5   17.    11.2   10.8
#   10.5   70.    39.2    7.7   71.  ] battery-capacity
# [ 9.    8.   16.   10.3  19.    9.6  16.5  -1.   21.    8.5   9.3   9.8
#  18.   10.    9.9  11.   17.    9.5  10.4   8.8  10.2  10.5  10.8   9.2
#  22.    9.7  17.9  10.7  10.1  18.3  11.2   8.2   8.75 11.3  23.   10.25
#   7.3  11.1  18.4  18.1   8.3   8.6  10.6  21.9   6.   16.2  15.6  19.2
#   9.1  22.5   8.9  11.8   9.4  19.5  19.4  15.5  18.2  10.55 11.65 17.6
#   7.   22.2   7.7  14.8   8.4  13.   17.5  14.    9.75  6.5   7.8  16.8
#  18.8  15.4   7.4   7.5  11.5  17.1  12.5  20.7  17.3  18.5  12.   15.7
#  10.9  16.7  12.8   8.7  15.8  21.1  12.3  18.6  22.4  23.4  21.5  20.1
#   8.1  22.6  17.7  17.8   6.1  21.2  22.8  11.7   9.25 12.1   7.6   8.55
#  16.4  21.3  16.1  15.   20.9  11.25 21.8   7.2   8.65  6.7  17.4  16.25
#  11.4  22.25  7.1   9.36 20.   16.9  15.2  15.3  20.3  13.5  16.3  12.2
#   6.8   7.9  20.5   6.6  12.7  15.9   9.44  5.6   9.45 22.3   8.25 11.6
#  21.7  18.45 12.6   9.35  9.85 19.1  15.34 15.1   6.25  6.2  16.6  10.75
#   9.91  6.85  7.75 23.5  18.7  12.4  19.8  14.9   8.95 13.6  22.1  20.6
#  15.38 20.2  17.2  13.2   6.4  20.8  22.9   7.25 19.3  13.4  22.7  14.4
#   5.3   5.5   6.73 11.05 12.9   5.8  13.3   6.9 ] compression
# [ 4.3  -1.    4.2   6.    4.7  11.   15.8   6.5   9.8   5.1  10.5   8.8
#   6.6   8.2   5.9   5.7   5.8   5.2   8.    6.1   8.5   7.8  11.9   9.
#  11.7  13.    6.7   8.1   7.5   5.3   7.2   9.3   8.4   9.6   9.4  11.4
#   4.9  14.2   5.   13.1   7.9   6.8   4.8   6.2   4.5   7.7   9.1  12.4
#   7.4  18.   13.8   7.6  11.2   8.3   6.9  11.8  10.3   3.6   5.5   7.1
#  11.1   8.7   6.3   4.1  10.7   8.9  10.8  16.    9.5  10.6   9.2  10.4
#   7.    1.5   9.7  11.6   3.9   4.    8.6  11.5   5.6   6.4  10.2  12.
#   1.695e+03  1.317e+03  1.623e+03  1.679e+03  1.308e+03  1.357e+03
#   1.880e+03  1.311e+03  1.436e+03  1.726e+03  1.256e+03  1.701e+03
#   1.396e+03  1.748e+03  1.283e+03  1.616e+03  1.678e+03  1.840e+03
#   1.230e+03  1.294e+03  1.659e+03  1.690e+03  1.709e+03  1.334e+03
#   1.266e+03  1.292e+03  1.168e+03  1.050e+03  1.303e+03  1.208e+03
#   1.227e+03  1.242e+03  1.722e+03  1.353e+03  1.728e+03  1.416e+03
#   1.687e+03  1.703e+03  1.206e+03  1.860e+03  1.161e+03  1.750e+03] configurations_back-wheel-base
# [ 40. 108.  55.  62.  45.  48.  -1.  75.  71.  60.  52.  90.  70.  80.
#   50.  72.  65.  78.  56.  64. 117.  87.  46.  32.  37.  57.  58.  63.
#   85.  54.  68.  83.  35.  33.  30.  42.  61.  76.  95.  97.  47.  66.
#   34.  53. 100. 114.  41.  88.  98.  49.  38. 113.  36.  44.  51.  79.
#   59.  67. 159.  28.  69.  81.  82.  74. 121. 102.  93.  96. 129.  86.
#   27.  73.  91. 106.  84. 104.  43. 152.  25.  39.  77. 120.  24.  31.
#  130. 150.  94.  89. 105.  92. 166. 128. 140.  20.  22. 115. 116. 110.
#  123. 119. 136.  26. 127. 165. 135. 109.  16. 107.  21. 112.] configurations_tank-volume
# [ 2.018e+03  1.993e+03  2.019e+03  2.003e+03  2.005e+03  2.017e+03
#  -1.000e+00  1.980e+03  2.007e+03  1.988e+03  1.996e+03  2.000e+03
#   2.011e+03  1.997e+03  2.002e+03  2.008e+03  2.006e+03  2.009e+03
#   1.981e+03  1.998e+03  1.978e+03  2.014e+03  2.010e+03  1.992e+03
#   2.001e+03  1.987e+03  2.004e+03  2.013e+03  2.015e+03  1.982e+03
#   1.999e+03  1.995e+03  2.012e+03  1.976e+03  1.990e+03  1.970e+03
#   1.972e+03  1.989e+03  2.016e+03  1.953e+03  1.986e+03  1.991e+03
#   1.994e+03  1.985e+03  1.984e+03  1.979e+03  1.961e+03  1.966e+03
#   1.933e+03  1.975e+03  1.948e+03  1.974e+03  1.959e+03  1.964e+03
#   1.971e+03  1.973e+03  1.940e+03  1.909e+03  1.957e+03  1.983e+03
#   1.968e+03  1.977e+03  1.939e+03  1.888e+03  1.949e+03  1.952e+03
#   1.967e+03  1.969e+03  1.963e+03  1.962e+03  1.958e+03  1.950e+03
#   1.943e+03  1.942e+03  1.955e+03  1.954e+03  1.960e+03  1.932e+03
#   1.931e+03  1.945e+03  1.941e+03  1.965e+03  1.956e+03  1.937e+03
#   1.951e+03  1.928e+03  1.936e+03  2.021e+03  1.923e+03  1.938e+03
#   1.944e+03  1.929e+03  1.935e+03  1.946e+03  1.926e+03  1.927e+03
#   1.947e+03] supergen_year-stop

# %% [markdown]
# Для преобразования воспользуемся функцией <code>np.log1p</code>, вместо <code>np.log</code>, предварительно заменив отрицательные значения на средние

# %%
from sklearn.impute import SimpleImputer

X_5[X_5 < 0] = np.nan

imputer = SimpleImputer(strategy="median")
X_5 = imputer.fit_transform(X_5)

transformed_X_5 = np.log1p(X_5)
train_X_log, test_X_log, train_y, test_y = train_test_split(transformed_X_5, y, test_size=0.33, random_state=42)

# %%
reg_log = LinearRegression().fit(train_X_log, train_y)

# %%
mean_squared_error(reg_log.predict(train_X_log), train_y), mean_squared_error(reg_log.predict(test_X_log), test_y)
# Out:
# (np.float64(23458.35575125369), np.float64(24360.368827990154))

# %% [markdown]
# Получили наименьшее значение MSE из всех рассмотренных моделей

# %% [markdown]
# ## Преобразование Бокса-Кокса

# %%
from scipy. stats import boxcox

# %%
X_6 = X.copy()
X_6.columns
# Out:
# Index(['back-suspension', 'battery-capacity', 'charge-time', 'compression',
#        'consumption-mixed', 'cylinders-order', 'cylinders-value',
#        'engine-feeding', 'engine-start', 'engine-stop', 'engine-type',
#        'gear-type', 'luxury', 'max-speed', 'power-electro-kw', 'supply-system',
#        'valves', 'valvetrain', 'weight', 'configurations_auto-premiere',
#        'configurations_back-wheel-base', 'configurations_front-brake',
#        'configurations_safety-rating', 'configurations_seats',
#        'configurations_tank-volume', 'supergen_year-stop',
#        'models_country-from', 'models_group', 'models_light-and-commercial',
#        'models_male'],
#       dtype='object')

# %% [markdown]
# Для преобразования Бокса-Кокса нужно, чтобы значения столбцов были положительными

# %%
X_6[X_6 < 0] = np.nan
imputer = SimpleImputer(strategy="median")
X_6_pos = imputer.fit_transform(X_6)
X_6_pos
# Out:
# array([[9.0000e+00, 2.2000e+01, 3.6457e+04, ..., 3.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [3.0000e+00, 2.2000e+01, 4.4872e+04, ..., 3.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [3.0000e+00, 2.2000e+01, 5.5927e+04, ..., 3.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        ...,
#        [3.0000e+00, 2.2000e+01, 8.9580e+03, ..., 3.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [3.0000e+00, 2.2000e+01, 2.0293e+04, ..., 3.0000e+00, 0.0000e+00,
#         1.0000e+00],
#        [1.0000e+01, 2.2000e+01, 5.2459e+04, ..., 3.0000e+00, 0.0000e+00,
#         0.0000e+00]])

# %%
X_6_pos = pd.DataFrame(X_6_pos, columns=['back-suspension', 'battery-capacity', 'charge-time', 'compression',
       'consumption-mixed', 'cylinders-order', 'cylinders-value',
       'engine-feeding', 'engine-start', 'engine-stop', 'engine-type',
       'gear-type', 'luxury', 'max-speed', 'power-electro-kw', 'supply-system',
       'valves', 'valvetrain', 'weight', 'configurations_auto-premiere',
       'configurations_back-wheel-base', 'configurations_front-brake',
       'configurations_safety-rating', 'configurations_seats',
       'configurations_tank-volume', 'supergen_year-stop',
       'models_country-from', 'models_group', 'models_light-and-commercial',
       'models_male'])

# %%
transformed_data, best_lambda = boxcox(X_6_pos['max-speed'])

sns.distplot(transformed_data, hist=False , kde=True)
plt.show()
# Out:
# C:\Users\96234\AppData\Local\Temp\ipykernel_3428\2858693548.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(transformed_data, hist=False , kde=True)

# %%
def boxcox_trans(df):
    df_trans = df.copy()
    lambdas = {} 

    for i in df.columns:  # Применяем только к числовым данным
        if (df[i] <= 0).any():
            med_value = df[i][df[i] > 0].median() 
            df_trans[i] = df[i].apply(lambda x: med_value if x <= 0 else x) 

        if df_trans[i].nunique() < 2:
            lambdas[i] = None
            continue
            
        df_trans[i], lambda_ = boxcox(df_trans[i])
        lambdas[i] = lambda_ 

    return df_trans, lambdas

# %%
X_6_trans, lambdas = boxcox_trans(X_6_pos)

# %%
train_X_6, test_X_6, train_y, test_y = train_test_split(X_6_trans, y, test_size=0.33, random_state=42)

# %%
reg_bc = LinearRegression().fit(train_X_6, train_y)

# %%
mean_squared_error(reg_bc.predict(train_X_6), train_y), mean_squared_error(reg_bc.predict(test_X_6), test_y)
# Out:
# (np.float64(53471.37665674923), np.float64(56639.628018793446))

# %% [markdown]
# Получили наибольшее значение MSE

# %%
X_b_bc = X_best.copy()
X_b_bc.head()
# Out:
#    cylinders-value  configurations_tank-volume  cylinders-order  weight  \
# 0                3                        40.0                0   820.0
# 1                7                       108.0                3  2350.0
# 2                4                        55.0                0  1350.0
# 3                4                        55.0                0  1090.0
# 4                4                        62.0                0  1410.0
#
#    configurations_seats  configurations_front-brake  engine-start  \
# 0                    13                           1          2006
# 1                    13                           4          1982
# 2                    13                           4          2014
# 3                    13                           4          2000
# 4                    13                           4          2000
#
#    models_country-from  consumption-mixed  engine-type  supergen_year-stop  \
# 0                   16                4.3            2              2018.0
# 1                   34               -1.0            2              1993.0
# 2                   35                4.2            0              2019.0
# 3                   10               -1.0            2              2003.0
# 4                   10               -1.0            0              2005.0
#
#    engine-stop  back-suspension
# 0         2018                9
# 1         1993                3
# 2         2018                3
# 3         2003                0
# 4         2005                8

# %%
X_b_bc_trans, lambdas = boxcox_trans(X_b_bc)

# %%
train_X_b_bc, test_X_b_bc, train_y, test_y = train_test_split(X_b_bc_trans, y, test_size=0.33, random_state=42)

# %%
reg_b_bc = LinearRegression().fit(train_X_b_bc, train_y)

# %%
mean_squared_error(reg_b_bc.predict(train_X_b_bc), train_y), mean_squared_error(reg_b_bc.predict(test_X_b_bc), test_y)
# Out:
# (np.float64(53487.514595205095), np.float64(56654.85460290138))

# %% [markdown]
# # Вывод:

# %% [markdown]
# ### наименьший MSE (24360.3688) получили после логарифмирования. Дополнительно можно провести логарифмирование только тех столбцов, которые имеют наилучшую связь с результирующей переменной (target)

# %%
X_b_log = X_best.copy()
X_b_log.head(1)
# Out:
#    cylinders-value  configurations_tank-volume  cylinders-order  weight  \
# 0                3                        40.0                0   820.0
#
#    configurations_seats  configurations_front-brake  engine-start  \
# 0                    13                           1          2006
#
#    models_country-from  consumption-mixed  engine-type  supergen_year-stop  \
# 0                   16                4.3            2              2018.0
#
#    engine-stop  back-suspension
# 0         2018                9

# %%
X_b_log[X_b_log < 0] = np.nan

imputer = SimpleImputer(strategy="median")
X_b_log = imputer.fit_transform(X_b_log)

transformed_X_b_log = np.log1p(X_b_log)
train_X_b_log, test_X_b_log, train_y, test_y = train_test_split(transformed_X_b_log, y, test_size=0.33, random_state=42)

# %%
reg_b_log = LinearRegression().fit(train_X_b_log, train_y)

# %%
mean_squared_error(reg_b_log.predict(train_X_b_log), train_y), mean_squared_error(reg_b_log.predict(test_X_b_log), test_y)
# Out:
# (np.float64(25510.25499941767), np.float64(26449.107761506348))

# %% [markdown]
# MSE в данном случае выше, чем при использовании всех объясняющих переменных в модели
